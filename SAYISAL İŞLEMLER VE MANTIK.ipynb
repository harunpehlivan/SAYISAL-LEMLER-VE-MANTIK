# %%
a = 2
b = 4
c = 100

# %%
a+b
# Out:
# 6

# %%
a-c
# Out:
# -98

# %%
a**2
# Out:
# 4

# %%
2**2
# Out:
# 4

# %%
2**3
# Out:
# 8

# %%
5%2
# Out:
# 1

# %%
5>2
# Out:
# True

# %%
5<2
# Out:
# False

# %%
a>a-1
# Out:
# True

# %%
a>a+1
# Out:
# False

# %%
a
# Out:
# 2

# %%
2==3
# Out:
# False

# %%
5/2 == 0
# Out:
# False

# %%
5/2 == 2.5
# Out:
# True
